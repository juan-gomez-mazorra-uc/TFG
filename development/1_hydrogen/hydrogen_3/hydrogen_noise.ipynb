# %% [markdown]
# ### Hydrogen

# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
from qiskit_algorithms import VQE
from qiskit_nature.units import DistanceUnit
from qiskit_algorithms.optimizers import COBYLA, SLSQP, SPSA
from qiskit_algorithms import NumPyMinimumEigensolver
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_aer.primitives import Estimator as AerEstimator
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD

# %%
optimizer = SPSA
optimizer_str = 'SPSA'

# %% [markdown]
# ##### Functions

# %%
def vqe_algorithm(shots, optimizer, maxiter, seed=170):
    driver = PySCFDriver(
        atom=f"H 0 0 0; H 0 0 0.735",
        basis="sto3g",
        charge=0,
        spin=0,
        unit=DistanceUnit.ANGSTROM,
    )
    problem = driver.run()
    mapper = JordanWignerMapper()

    fermionic_op = problem.hamiltonian.second_q_op()

    # define ansatz and optimizer
    num_spatial_orbitals = int(fermionic_op.num_spin_orbitals/2)
    num_particles = (1, 1)
    ansatz = UCCSD(
        num_spatial_orbitals,
        num_particles,
        mapper,
        initial_state=HartreeFock(
            num_spatial_orbitals,
            num_particles,
            mapper,
        ),
    )

    noiseless_estimator = AerEstimator(
        run_options={"seed": seed, "shots": shots},
        transpile_options={"seed_transpiler": seed},
    )

    vqe = VQE(noiseless_estimator, ansatz, optimizer=optimizer(maxiter=maxiter))

    return vqe, ansatz

# %%
def vqe_distance(solver, vqe, distance):
    # build the model:
    driver = PySCFDriver(
        atom=f"H 0 0 0; H 0 0 {distance}",
        basis="sto3g",
        charge=0,
        spin=0,
        unit=DistanceUnit.ANGSTROM,
    )

    # it'll return an instance of ElectronicStructureProblem:
    problem = driver.run()

    mapper = JordanWignerMapper()
    fermionic_op = problem.hamiltonian.second_q_op()
    qubit_op = mapper.map(fermionic_op)

    hamiltonian = problem.hamiltonian
    result = solver.solve(problem)

    """
    vqe.estimator = noisy_estimator
    """

    result_vqe = vqe.compute_minimum_eigenvalue(operator=qubit_op)
    
    return (hamiltonian, result, result_vqe)

# %%
def save_csv(distances, energies, energies_vqe, path):

    folder = path.split('/')[0]
    if not os.path.exists(folder):
        os.makedirs(folder)
    
    with open(path, mode='w', newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        escritor_csv.writerow(['distance', 'energy', 'energy_vqe'])
        for x, y, z in zip(distances, energies, energies_vqe):
            escritor_csv.writerow([x, y, z])

# %%
def save_plt(distances, energies, energies_vqe, path, shots):

    folder = path.split('/')[0]
    if not os.path.exists(folder):
        os.makedirs(folder)

    plt.plot(distances, energies, marker='', linestyle='-', label='Exact solution')
    plt.plot(distances, energies_vqe, marker='', linestyle='-', label=f'UCCSD / {optimizer_str} / shots={shots}')
    plt.xlabel('Bond length/Å')
    plt.ylabel('Energy/Hartree')
    plt.title('Hydrogen Molecule')
    plt.legend()
    plt.show()
    plt.savefig(path)

# %% [markdown]
# ##### Code

# %%
solver = GroundStateEigensolver(
        JordanWignerMapper(),
        NumPyMinimumEigensolver(),
    )

# %%
distances = np.linspace(0.25, 4, 200)
shots_list = [16, 128, 1024, 16384]

for shots in shots_list:
    energies = []
    energies_vqe = []

    vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
    
    for distance in distances:
        vqe.initial_point = np.zeros(ansatz.num_parameters)
        hamiltonian, result, result_vqe = vqe_distance(solver, vqe, distance)

        energies.append(result.groundenergy + hamiltonian.nuclear_repulsion_energy)
        energies_vqe.append(result_vqe.eigenvalue.real + hamiltonian.nuclear_repulsion_energy)

    path_csv = f'results_{optimizer_str}/shots={shots}.csv'
    path_plt = f'results_{optimizer_str}/shots={shots}.png'
    
    save_csv(distances, energies, energies_vqe, path_csv)
    save_plt(distances, energies, energies_vqe, path_plt, shots)
# Out:
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# ...
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# /tmp/ipykernel_960/1856013622.py:9: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 10
#       8 for distance in distances:
#       9     vqe, ansatz = vqe_algorithm(shots, optimizer, maxiter=100, seed=100)
# ---> 10     hamiltonian, result, result_vqe = vqe_distance(solver, vqe, distance)
#      12     energies.append(result.groundenergy + hamiltonian.nuclear_repulsion_energy)
#      13     energies_vqe.append(result_vqe.eigenvalue.real + hamiltonian.nuclear_repulsion_energy)
#
# Cell In[44], line 19, in vqe_distance(solver, vqe, distance)
#      16 qubit_op = mapper.map(fermionic_op)
#      18 hamiltonian = problem.hamiltonian
# ---> 19 result = solver.solve(problem)
#      21 """
#      22 vqe.estimator = noisy_estimator
#      23 """
#      25 result_vqe = vqe.compute_minimum_eigenvalue(operator=qubit_op)
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/qiskit_nature/second_q/algorithms/ground_state_solvers/ground_state_eigensolver.py:72, in GroundStateEigensolver.solve(self, problem, aux_operators)
#      57 def solve(
#      58     self,
#      59     problem: BaseProblem,
#      60     aux_operators: dict[str, SparseLabelOp | SparsePauliOp] | None = None,
#      61 ) -> EigenstateResult:
#      62     """Compute Ground State properties.
#      63
#      64     Args:
#    (...)
#      70         :meth:`~.BaseProblem.interpret`.
#      71     """
# ---> 72     main_operator, aux_ops = self.get_qubit_operators(problem, aux_operators)
#      73     raw_mes_result = self.solver.compute_minimum_eigenvalue(main_operator, aux_ops)
#      75     eigenstate_result = EigenstateResult.from_result(raw_mes_result)
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/qiskit_nature/second_q/algorithms/ground_state_solvers/ground_state_eigensolver.py:89, in GroundStateEigensolver.get_qubit_operators(self, problem, aux_operators)
#      86 main_second_q_op, aux_second_q_ops = problem.second_q_ops()
#      88 main_operator = self._qubit_mapper.map(main_second_q_op)
# ---> 89 aux_ops = self._qubit_mapper.map(aux_second_q_ops)
#      91 if aux_operators is not None:
#      92     for name_aux, aux_op in aux_operators.items():
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/qiskit_nature/second_q/mappers/fermionic_mapper.py:33, in FermionicMapper.map(self, second_q_ops, register_length)
#      27 def map(
#      28     self,
#      29     second_q_ops: FermionicOp | ListOrDictType[FermionicOp],
#      30     *,
#      31     register_length: int | None = None,
#      32 ) -> SparsePauliOp | ListOrDictType[SparsePauliOp]:
# ---> 33     return super().map(second_q_ops, register_length=register_length)
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/qiskit_nature/second_q/mappers/qubit_mapper.py:165, in QubitMapper.map(self, second_q_ops, register_length)
#     163 qubit_ops: _ListOrDict = _ListOrDict()
#     164 for name, second_q_op in iter(wrapped_second_q_ops):
# --> 165     qubit_ops[name] = self._map_single(second_q_op, register_length=register_length)
#     167 returned_ops = qubit_ops.unwrap(wrapped_type)
#     168 # Note the output of the mapping will never be None for standard mappers other than the
#     169 # TaperedQubitMapper.
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/qiskit_nature/second_q/mappers/qubit_mapper.py:140, in QubitMapper._map_single(self, second_q_op, register_length)
#     125 def _map_single(
#     126     self, second_q_op: SparseLabelOp, *, register_length: int | None = None
#     127 ) -> SparsePauliOp:
#     128     """Maps a :class:`~qiskit_nature.second_q.operators.SparseLabelOp`
#     129     to a ``SparsePauliOp``.
#     130
#    (...)
#     138         The qubit operator corresponding to the problem-Hamiltonian in the qubit space.
#     139     """
# --> 140     return self.mode_based_mapping(second_q_op, register_length=register_length)
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/qiskit_nature/second_q/mappers/qubit_mapper.py:266, in QubitMapper.mode_based_mapping(cls, second_q_op, register_length)
#     264     ret_op = ret_op.compose(times_creation_op[position], front=True).simplify()
#     265 elif char == "-":
# --> 266     ret_op = ret_op.compose(times_annihilation_op[position], front=True).simplify()
#     267 # catch any disallowed labels
#     268 else:
#     269     raise QiskitNatureError(
#     270         f"FermionicOp label included '{char}'. Allowed characters: I, N, E, +, -"
#     271     )
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/qiskit/quantum_info/operators/symplectic/sparse_pauli_op.py:491, in SparsePauliOp.simplify(self, atol, rtol)
#     487     is_zero = np.array(
#     488         [np.isclose(to_complex(coeff), 0, atol=atol, rtol=rtol) for coeff in coeffs]
#     489     )
#     490 else:
# --> 491     is_zero = np.isclose(coeffs, 0, atol=atol, rtol=rtol)
#     492 # Check edge case that we deleted all Paulis
#     493 # In this case we return an identity Pauli with a zero coefficient
#     494 if np.all(is_zero):
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/numpy/core/numeric.py:2351, in isclose(a, b, rtol, atol, equal_nan)
#    2349 yfin = isfinite(y)
#    2350 if all(xfin) and all(yfin):
# -> 2351     return within_tol(x, y, atol, rtol)
#    2352 else:
#    2353     finite = xfin & yfin
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/numpy/core/numeric.py:2331, in isclose.<locals>.within_tol(x, y, atol, rtol)
#    2330 def within_tol(x, y, atol, rtol):
# -> 2331     with errstate(invalid='ignore'), _no_nep50_warning():
#    2332         return less_equal(abs(x-y), atol + rtol * abs(y))
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/numpy/core/_ufunc_config.py:431, in errstate.__enter__(self)
#     430 def __enter__(self):
# --> 431     self.oldstate = seterr(**self.kwargs)
#     432     if self.call is not _Unspecified:
#     433         self.oldcall = seterrcall(self.call)
#
# File ~/TFG/tfg_env/lib/python3.10/site-packages/numpy/core/_ufunc_config.py:128, in seterr(all, divide, over, under, invalid)
#     122 maskvalue = ((_errdict[divide] << SHIFT_DIVIDEBYZERO) +
#     123              (_errdict[over] << SHIFT_OVERFLOW) +
#     124              (_errdict[under] << SHIFT_UNDERFLOW) +
#     125              (_errdict[invalid] << SHIFT_INVALID))
#     127 pyvals[1] = maskvalue
# --> 128 umath.seterrobj(pyvals)
#     129 return old
#
# KeyboardInterrupt:
